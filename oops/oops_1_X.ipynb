# %%
l=[1,2,3]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-695798479.py in <cell line: 0>()
#       1 l=[1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# every thing is in python is a object

# %% [markdown]
# different between oops and procedural approch (oops is a modular coding and another one is a line by line coding )

# %% [markdown]
# after learning the oops programmer can make own custmize datatype

# %% [markdown]
# ![image.png](data:image/png;base64,...) M

# %%
#syntax to create an object
# objectname=classname()
l=[1,2,3]
l=list()
l
# Out:
# []

# %%
s=str()
s
# Out:
# ''

# %%
class Atm():
  # constructor
  def __init__(self):
    self.pin = ''
    self.balance = 0
    print("I am constructor")
    self.menu()

  def menu(self):
    user_input = input("""
    Hi, how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Exit
    """)
    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.Blnce()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input("Enter your pin: ")
    self.pin = user_pin
    user_balance = int(input('Enter balance: '))
    self.balance = user_balance
    print("Password created successfully")
    self.menu()

  def change_pin(self):
    prev_passwd = input("Enter the old password: ")
    if prev_passwd == self.pin:
      new_passwd = input("Enter the new password: ")
      self.pin = new_passwd
      print("Password changed successfully")
    else:
      print("Wrong password entered")
    self.menu()

  def Blnce(self):
    prev_passwd = input("Enter your password: ")
    if prev_passwd == self.pin:
      print("Login successful")
      print("Balance:", self.balance)
    else:
      print("Login unsuccessful")
    self.menu()

  def withdraw(self):
    prev_passwd = input("Enter your password: ")
    if prev_passwd == self.pin:
      amt = int(input("Enter the amount: "))
      if amt <= self.balance:
        self.balance -= amt  # update balance
        print("Transaction successful")
        print("Your current balance is:", self.balance)
      else:
        print("Insufficient balance!!!")
    else:
      print("Wrong password entered")
    self.menu()

# %%
obj=Atm()
# Out:
# I am constructor
#
#     Hi, how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Exit
#     5

# %%
type(obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2322519186.py in <cell line: 0>()
# ----> 1 type(obj)
#
# NameError: name 'obj' is not defined

# %%
l=[1,2,3]
len(l) # len is a function
l.append(5) # append is a method

# %% [markdown]
# # class diagram

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #magic method

# %%
# formate:- '__name__ '

# %% [markdown]
# what is constructor is a method but special method it has a superpower which is we dont have to call explicitly it automatically called when object is created

# %% [markdown]
# #faida ky hai ?  ..." configuration related code like when app is open the it autometically connect to database or server "

# %% [markdown]
# golden rule :- class ke andar jo kuch bhi hai use sirf us class ka object he access kr sakta hai

# %%
# one question :- consider in above if change_pin() function want to call withdraw() then can he able to call???? .......ans is no read goldel rule ...it is only possible with "self"

# %% [markdown]
# @ actually who is self :- self is none otherthan its a object because id(self) and id(object) have same address of memory location

# %% [markdown]
# @ but why self is seating inside the class ????..........because in oops ek function another function ko call nii kr sakta directoly but when we required to call some another function the we use the self to call that because read golden rule

# %% [markdown]
# now we want to create a fraction class

# %%
class fraction :
  #parameterized constructor
  def __init__(self,x,y):
    self.num=x
    self.den=y

# %%
fr1=fraction(3,4) # abhi mai dekhna chahu ki mera fraction object dikhta kaise hai to dekho niche kuch samaj nii aa rha.....so now we use __str__
print(fr1)

# %%
class fraction :
  #parameterized constructor
  def __init__(self,x,y):
    self.num=x
    self.den=y
  def __str__(self):
    return (f"{self.num}/{self.den}")

  def __add__(self,other) :
    new_num=self.num*other.den + self.den*other.num
    new_den=self.den*other.den
    return (f'{new_num}/{new_den}')
  def __sub__(self,other) :
    new_num=self.num*other.den - self.den*other.num
    new_den=self.den*other.den
    return (f'{new_num}/{new_den}')
  def __mul__(self,other):
    new_num=self.num*other.num
    new_den=self.den*other.den
    return (f'{new_num}/{new_den}')
  def __truediv__(self,other):
    new_num=self.num*other.den
    new_den=self.den*other.num
    return (f'{new_num}/{new_den}')

# %%
obj1=fraction(3,4)
obj2=fraction(4,5)

# %% [markdown]
# but now if we want to do "obj1 + obj2 "

# %%
print(obj1 + obj2)
print(obj1 - obj2)
print(obj1 * obj2)
print(obj1 / obj2)
# Out:
# 31/20
# -1/20
# 12/20
# 15/16
